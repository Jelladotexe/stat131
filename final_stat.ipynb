# %% [markdown]
# <a href="https://colab.research.google.com/github/Jelladotexe/stat131/blob/main/final_stat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Est para

# %% [markdown]
# ![Screenshot 2569-03-24 at 00.14.57.png](data:image/png;base64,...)

# %%
# 8.1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 8.2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 8.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 8.4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 8.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 8.6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 8.7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 8.8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 8.9

# %% [markdown]
# # Hypo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.11

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.12

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.13

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.14

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.15

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 9.16

# %% [markdown]
# # Chi Square

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 10.1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 10.2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 10.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 10.4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 10.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 10.6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 10.7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 10.8
df = pd.read_csv("https://raw.githubusercontent.com/ThammakornS/ProgStat/main/dataset/titanic.csv")

# %% [markdown]
# # Corr

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 11.1
df = pd.read_csv("https://raw.githubusercontent.com/ThammakornS/ProgStat/main/dataset/sale.csv")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 11.2
df = pd.read_csv("https://raw.githubusercontent.com/ThammakornS/ProgStat/main/dataset/sale.csv")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 11.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 11.4
df = pd.read_csv("https://raw.githubusercontent.com/ThammakornS/ProgStat/main/dataset/cosmetic.csv")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 11.5
df = pd.read_csv("https://raw.githubusercontent.com/ThammakornS/ProgStat/main/dataset/sale.csv")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 11.6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 11.7
df = pd.read_csv("https://raw.githubusercontent.com/ThammakornS/ProgStat/main/dataset/cosmetic.csv")
